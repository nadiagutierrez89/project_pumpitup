# %% [markdown]
# # Qué hace este notebook???
#
# En este notebook se entrena una nueva red neuronal desde cero, usando un dataset de spectrogramas y datos de pasos asociados.
#
# Luego se prueba la red con algunas imágenes de ejemplo.

# %%
from ai import PumpIA

pia = PumpIA()
pia.load_dataset(
    dataset_json_path="./fake_ds.json", 
    train_sgrams_root_path="./sgrams",
)

pia.show_sgrams(sample=3)
# Out:
# Reading spectrogram images...
# Loaded 1918 spectrograms

# %%
pia.build_and_train_neural_network(train_epochs=5)
pia.save("./ia_entrenada.pkl")
# Out:
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 343ms/step - binary_accuracy: 0.6120 - loss: 0.6726 - val_binary_accuracy: 0.7676 - val_loss: 0.5842
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - binary_accuracy: 0.9252 - loss: 0.3751 - val_binary_accuracy: 0.9264 - val_loss: 0.2663
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - binary_accuracy: 0.9967 - loss: 0.0999 - val_binary_accuracy: 0.9622 - val_loss: 0.1299
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - binary_accuracy: 0.9992 - loss: 0.0307 - val_binary_accuracy: 0.9867 - val_loss: 0.0483
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - binary_accuracy: 1.0000 - loss: 0.0133 - val_binary_accuracy: 0.9854 - val_loss: 0.0409

# %%
# solo obtener una predicción
pia.predict("./sgrams/fisa_pared_mp4_300.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# '11111111111111111111'

# %%
# obtener una predicción pero mirar un poco más en detalle la imagen, la predicción cruda interna, etc
pia.show_and_predict("./sgrams/fisa_pared_mp4_300.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Prediction:
# 11111111111111111111
# Raw prediction:
# [0.9951088  0.9980332  0.9957424  0.99770975 0.9942525  0.9964612
#  0.9929669  0.9943836  0.9944013  0.9938724  0.9945287  0.9981458
#  0.9950305  0.9908048  0.9975821  0.9948761  0.9938969  0.9935334
#  0.9970504  0.996454  ]
