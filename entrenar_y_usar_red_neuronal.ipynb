# %%
from ai import PumpIA

# %%
pia = PumpIA()
pia.load_dataset(
    dataset_json_path="./fake_ds.json", 
    train_sgrams_root_path="./sgrams",
)
# Out:
# Reading spectrogram images...
# Loaded 1918 spectrograms

# %%
pia.show_sgrams(sample=3)

# %%
pia.build_and_train_neural_network(train_epochs=5)
# Out:
# Epoch 1/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 373ms/step - binary_accuracy: 0.6412 - loss: 0.6353 - val_binary_accuracy: 0.7855 - val_loss: 0.5425
# Epoch 2/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 435ms/step - binary_accuracy: 0.9454 - loss: 0.3193 - val_binary_accuracy: 0.9526 - val_loss: 0.2425
# Epoch 3/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - binary_accuracy: 0.9939 - loss: 0.0966 - val_binary_accuracy: 0.9447 - val_loss: 0.1596
# Epoch 4/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 474ms/step - binary_accuracy: 0.9968 - loss: 0.0338 - val_binary_accuracy: 0.9868 - val_loss: 0.0567
# Epoch 5/5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - binary_accuracy: 0.9999 - loss: 0.0148 - val_binary_accuracy: 0.9889 - val_loss: 0.0351

# %%
pia.show_and_predict("./sgrams/fisa_aula_mp4_007.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Prediction:
# 00000000000000000000
# Raw prediction:
# [0.0772404  0.15910207 0.16135408 0.13239576 0.13665925 0.14117022
#  0.17277215 0.18974744 0.1513805  0.07777552 0.14890197 0.16471943
#  0.17317468 0.11671325 0.14415787 0.24388994 0.14740095 0.12336644
#  0.14885178 0.1305773 ]

# %%
pia.show_and_predict("./sgrams/fisa_pared_mp4_300.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Prediction:
# 11111111111111111111
# Raw prediction:
# [0.99776137 0.99478215 0.9922294  0.9927584  0.9956617  0.99524766
#  0.9964551  0.99509454 0.98849535 0.9969248  0.9986706  0.99434644
#  0.99724257 0.9945859  0.9973273  0.99121934 0.9946767  0.99895334
#  0.99624926 0.99484974]

# %%
# solo obtener una predicción
pia.predict("./sgrams/fisa_pared_mp4_300.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# '11111111111111111111'
